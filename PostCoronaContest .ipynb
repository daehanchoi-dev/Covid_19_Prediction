# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.graph_objects as go
from fbprophet import Prophet
import pycountry 

from collections import namedtuple

# %matplotlib inline
pd.set_option('display.float_format', lambda x : '{:.2f}'.format(x))

# %%
df_roam = pd.read_csv('../input/corona/Roaming_data.csv')
df_infect = pd.read_excel('../input/corona/Global_infection.xls')

# %%
df_infect.head()
# Out:
#             filename                                              title  \
# 0  AFRO2019120200003  WHO supports Angola’s Government efforts to en...
# 1  AFRO2019120300001  African First Ladies laud progress against HIV...
# 2  AFRO2019120300002               Eritrea Observed World AIDS Day 2019
# 3  AFRO2019120400003  West and Central Africa Expands Access to HIV ...
# 4  AFRO2019120400004  Nearly 23 million voluntary male medical circu...
#
#                                                  URL         CollectionDate  \
# 0  https://www.afro.who.int/news/who-supports-ang...  2019-12-02 21:00:16.0
# 1  https://www.afro.who.int/news/african-first-la...  2019-12-03 00:00:17.0
# 2  https://www.afro.who.int/news/eritrea-observed...  2019-12-03 00:00:18.0
# 3  https://www.afro.who.int/news/west-and-central...  2019-12-04 03:00:14.0
# 4  https://www.afro.who.int/news/nearly-23-millio...  2019-12-04 22:00:14.0
#
#               PostDate Channel                            Influenza  Class
# 0  2019-12-02 00:00:00    AFRO                        Poliomyelitis  Viral
# 1  2019-12-02 00:00:00    AFRO  Acquired immuno deficiency syndrome  Viral
# 2  2019-12-02 00:00:00    AFRO  Acquired immuno deficiency syndrome  Viral
# 3  2019-12-03 00:00:00    AFRO  Acquired immuno deficiency syndrome  Viral
# 4  2019-12-04 00:00:00    AFRO  Acquired immuno deficiency syndrome  Viral

# %%
df_roam.head()
# Out:
#      return iso   arrival  departure  count
# 0  20200131  ad  20200130   20200130      3
# 1  20200131  ae  20191231   20200125      3
# 2  20200131  ae  20191231   20200131      3
# 3  20200131  ae  20200102   20200102      3
# 4  20200131  ae  20200104   20200131      3

# %%
df_infect.drop(['filename', 'title', 'URL', 'CollectionDate', 'Channel', 'Class'], axis= 1, inplace=True)

# %%
df_infect.head()
# Out:
#               PostDate                            Influenza
# 0  2019-12-02 00:00:00                        Poliomyelitis
# 1  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3  2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4  2019-12-04 00:00:00  Acquired immuno deficiency syndrome

# %%
print('Influenza Count\n',df_infect.Influenza.value_counts(),'\n')
print('Influenza Percentage\n',df_infect.Influenza.value_counts('.'))
# Out:
# Influenza Count
#  COVID-19                             35238
# Influenza                             6760
# Dengue fever                          3945
# Measles                               1587
# Severe acute respiratory syndrome     1574
#                                      ...
# Paragonimiasis                           1
# Anisakiasis                              1
# Creutzfeldt Jakob disease                1
# Gnathostomiasis                          1
# Necrobacillosis                          1
# Name: Influenza, Length: 219, dtype: int64
#
# Influenza Percentage
#  COVID-19                            0.57
# Influenza                           0.11
# Dengue fever                        0.06
# Measles                             0.03
# Severe acute respiratory syndrome   0.03
#                                     ...
# Paragonimiasis                      0.00
# Anisakiasis                         0.00
# Creutzfeldt Jakob disease           0.00
# Gnathostomiasis                     0.00
# Necrobacillosis                     0.00
# Name: Influenza, Length: 219, dtype: float64

# %%
df_infect.Influenza.value_counts()
# Out:
# COVID-19                             35238
# Influenza                             6760
# Dengue fever                          3945
# Measles                               1587
# Severe acute respiratory syndrome     1574
#                                      ...
# Paragonimiasis                           1
# Anisakiasis                              1
# Creutzfeldt Jakob disease                1
# Gnathostomiasis                          1
# Necrobacillosis                          1
# Name: Influenza, Length: 219, dtype: int64

# %%
df = df_infect

# %%
for col in df.Influenza.value_counts():
    cnt=0
    if col == 1:
        del col
        cnt+=1
        
print(cnt)
# Out:
# 1

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df.Influenza.value_counts()
# Out:
# COVID-19                             35238
# Influenza                             6760
# Dengue fever                          3945
# Measles                               1587
# Severe acute respiratory syndrome     1574
#                                      ...
# Paragonimiasis                           1
# Anisakiasis                              1
# Creutzfeldt Jakob disease                1
# Gnathostomiasis                          1
# Necrobacillosis                          1
# Name: Influenza, Length: 219, dtype: int64

# %%
df = df[df.Influenza != 1]

# %%
df.Influenza.value_counts()
# Out:
# COVID-19                             35238
# Influenza                             6760
# Dengue fever                          3945
# Measles                               1587
# Severe acute respiratory syndrome     1574
#                                      ...
# Paragonimiasis                           1
# Anisakiasis                              1
# Creutzfeldt Jakob disease                1
# Gnathostomiasis                          1
# Necrobacillosis                          1
# Name: Influenza, Length: 219, dtype: int64

# %%
df
# Out:
# array(['Poliomyelitis', 'Acquired immuno deficiency syndrome',
#        'Acquired immuno deficiency syndrome', ..., 'Influenza',
#        'Influenza', 'Influenza'], dtype=object)

# %%
df_infect.drop(['filename', 'title', 'URL', 'CollectionDate', 'Channel', 'Class'], axis= 1, inplace=True)

# %%
df_infect.head()
# Out:
#               PostDate                            Influenza
# 0  2019-12-02 00:00:00                        Poliomyelitis
# 1  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3  2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4  2019-12-04 00:00:00  Acquired immuno deficiency syndrome

# %%
df.head()
# Out:
#               PostDate                            Influenza
# 0  2019-12-02 00:00:00                        Poliomyelitis
# 1  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3  2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4  2019-12-04 00:00:00  Acquired immuno deficiency syndrome

# %%
df.tail()
# Out:
#                   PostDate  Influenza
# 61719  2020-03-16 00:00:00  Influenza
# 61720  2020-03-16 00:00:00  Influenza
# 61721  2020-03-16 00:00:00  Influenza
# 61722  2020-03-15 00:00:00  Influenza
# 61723  2020-03-15 00:00:00  Influenza

# %%
df_qw = df

# %%
df_qw.head()
# Out:
#               PostDate                            Influenza
# 0  2019-12-02 00:00:00                        Poliomyelitis
# 1  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3  2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4  2019-12-04 00:00:00  Acquired immuno deficiency syndrome

# %%
df_qw.drop([0,2],0)
# Out:
#                   PostDate                            Influenza
# 1      2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3      2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4      2019-12-04 00:00:00  Acquired immuno deficiency syndrome
# 5      2019-12-04 00:00:00                        Poliomyelitis
# 6      2019-12-05 00:00:00  Acquired immuno deficiency syndrome
# ...                    ...                                  ...
# 61719  2020-03-16 00:00:00                            Influenza
# 61720  2020-03-16 00:00:00                            Influenza
# 61721  2020-03-16 00:00:00                            Influenza
# 61722  2020-03-15 00:00:00                            Influenza
# 61723  2020-03-15 00:00:00                            Influenza
#
# [61722 rows x 2 columns]

# %%
df_qw.drop([4],0)
# Out:
#                   PostDate                            Influenza
# 0      2019-12-02 00:00:00                        Poliomyelitis
# 1      2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2      2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3      2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 5      2019-12-04 00:00:00                        Poliomyelitis
# ...                    ...                                  ...
# 61719  2020-03-16 00:00:00                            Influenza
# 61720  2020-03-16 00:00:00                            Influenza
# 61721  2020-03-16 00:00:00                            Influenza
# 61722  2020-03-15 00:00:00                            Influenza
# 61723  2020-03-15 00:00:00                            Influenza
#
# [61723 rows x 2 columns]

# %%
df_qw.drop([df_qw.Influenza.unique()],0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-75abf00d2249> in <module>
# ----> 1 df_qw.drop(['df_qw.Influenza.unique()'],0)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['df_qw.Influenza.unique()'] not found in axis"

# %%
df.Influenza.value_counts()
# Out:
# COVID-19                             35238
# Influenza                             6760
# Dengue fever                          3945
# Measles                               1587
# Severe acute respiratory syndrome     1574
#                                      ...
# Paragonimiasis                           1
# Anisakiasis                              1
# Creutzfeldt Jakob disease                1
# Gnathostomiasis                          1
# Necrobacillosis                          1
# Name: Influenza, Length: 219, dtype: int64

# %%
df.head()
# Out:
#               PostDate                            Influenza
# 0  2019-12-02 00:00:00                        Poliomyelitis
# 1  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 2  2019-12-02 00:00:00  Acquired immuno deficiency syndrome
# 3  2019-12-03 00:00:00  Acquired immuno deficiency syndrome
# 4  2019-12-04 00:00:00  Acquired immuno deficiency syndrome

# %%
df.Influenza.index
